# %%
import pandas as pd

df = pd.read_csv('sample_submission.csv')
df
# Out:
#             id  target
# 0            5     0.5
# 1            6     0.5
# 2            8     0.5
# 3            9     0.5
# 4           11     0.5
# ...        ...     ...
# 199995  499983     0.5
# 199996  499984     0.5
# 199997  499987     0.5
# 199998  499994     0.5
# 199999  499998     0.5
#
# [200000 rows x 2 columns]

# %%
df = df.target

# %%
d = pd.read_csv("test.csv")
d
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont1  \
# 0            5    A    F    A    A    F   BI    A   AH   AX  ...  0.735690
# 1            6    A    H    C    A    E   AB    I    F    N  ...  0.313703
# 2            8    A    N    C    A    F   AB    A   AH   BC  ...  0.448201
# 3            9    B    L    C    A    F   BI    A    E   AX  ...  0.666092
# 4           11    A    F    A    B    F   BI    A   AH    I  ...  0.772229
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995  499983    A    N    A    D    F   BI    A   AF   AX  ...  0.361426
# 199996  499984    B    I    A    B    E   BI    A   AS    S  ...  0.551106
# 199997  499987    A    L    D    A    H   BI    A   AN    J  ...  0.812384
# 199998  499994    A    K    A    C    F   BI    A    R   BM  ...  0.811282
# 199999  499998    A    K    A    A    E   BI    C   AO   BM  ...  0.336168
#
# ...

# %%
d['target'] = df

# %%
d
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont2  \
# 0            5    A    F    A    A    F   BI    A   AH   AX  ...  0.578366
# 1            6    A    H    C    A    E   AB    I    F    N  ...  0.928885
# 2            8    A    N    C    A    F   AB    A   AH   BC  ...  0.424876
# 3            9    B    L    C    A    F   BI    A    E   AX  ...  0.598943
# 4           11    A    F    A    B    F   BI    A   AH    I  ...  0.479572
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995  499983    A    N    A    D    F   BI    A   AF   AX  ...  0.351946
# 199996  499984    B    I    A    B    E   BI    A   AS    S  ...  0.628843
# 199997  499987    A    L    D    A    H   BI    A   AN    J  ...  0.803348
# 199998  499994    A    K    A    C    F   BI    A    R   BM  ...  0.820635
# 199999  499998    A    K    A    A    E   BI    C   AO   BM  ...  0.270483
#
# ...

# %%
d.to_csv("test.csv")

# %%
d
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont2  \
# 0            5    A    F    A    A    F   BI    A   AH   AX  ...  0.578366
# 1            6    A    H    C    A    E   AB    I    F    N  ...  0.928885
# 2            8    A    N    C    A    F   AB    A   AH   BC  ...  0.424876
# 3            9    B    L    C    A    F   BI    A    E   AX  ...  0.598943
# 4           11    A    F    A    B    F   BI    A   AH    I  ...  0.479572
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995  499983    A    N    A    D    F   BI    A   AF   AX  ...  0.351946
# 199996  499984    B    I    A    B    E   BI    A   AS    S  ...  0.628843
# 199997  499987    A    L    D    A    H   BI    A   AN    J  ...  0.803348
# 199998  499994    A    K    A    C    F   BI    A    R   BM  ...  0.820635
# 199999  499998    A    K    A    A    E   BI    C   AO   BM  ...  0.270483
#
# ...
